# %% [markdown]
# <a href="https://colab.research.google.com/github/KamoTaueatsoala/ML-Projects/blob/main/irrigation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Constants
MAX_SENSOR_VALUE = 4095
MIN_TEMP = 10.0
MAX_TEMP = 45.0
MAX_HUMIDITY = 100.0

# Soil moisture thresholds
IN_WATER_THRESHOLD = 1400    # Sensor in water
WET_MOIST_THRESHOLD = 3400   # Wet to moist soil
OPEN_AIR_MIN = 3500          # Open air/dry soil
OPEN_AIR_MAX = 3699          # Open air maximum

def generate_water(soil, temp, humidity, hour):
    """Corrected water calculation with proper soil-water relationship"""
    if soil <= IN_WATER_THRESHOLD:
        return 0.0

    # Normalized soil moisture (0=wet, 1=dry)
    soil_norm = (soil - IN_WATER_THRESHOLD) / (OPEN_AIR_MAX - IN_WATER_THRESHOLD)

    # Base water needs - increases with soil dryness (higher ADC)
    if soil >= OPEN_AIR_MIN:
        base_water = 3.0 + soil_norm * 4.0  # 3.0-7.0ml for dry soil
    else:
        base_water = 1.0 + soil_norm * 2.0  # 1.0-3.0ml for moist soil

    # Environmental adjustments
    temp_adj = 2.0 * ((temp - MIN_TEMP) / (MAX_TEMP - MIN_TEMP))**1.5
    hum_adj = 1.0 * (1 - (humidity / MAX_HUMIDITY))**1.3

    # Time of day effect
    hour_adj = 0.8 * np.cos((hour - 14) * np.pi / 12)

    # Combine factors - soil dryness has strongest influence
    water_ml = base_water * 1.5 + temp_adj + hum_adj + hour_adj

    return max(0, water_ml)

def generate_features(soil, temp, humidity, hour):
    """Generate features with proper soil-water relationship"""
    temp_norm = (temp - MIN_TEMP) / (MAX_TEMP - MIN_TEMP)
    hum_norm = humidity / MAX_HUMIDITY
    soil_norm = (soil - IN_WATER_THRESHOLD) / (OPEN_AIR_MAX - IN_WATER_THRESHOLD)  # 0-1 scale

    return np.column_stack((
        soil_norm,  # Direct soil dryness measure
        temp_norm,
        hum_norm,
        np.sin(hour * np.pi / 12),
        np.cos(hour * np.pi / 12),
        soil_norm * temp_norm,  # Interaction terms
        soil_norm * hum_norm,
        temp_norm * hum_norm
    ))

def load_data():
    """Generate training data with proper soil-water relationship"""
    np.random.seed(42)
    num_samples = 30000

    # Generate soil values with proper distribution
    soil = np.concatenate([
        np.random.randint(0, IN_WATER_THRESHOLD, num_samples//5),
        np.random.triangular(IN_WATER_THRESHOLD, WET_MOIST_THRESHOLD, OPEN_AIR_MIN, num_samples//2),
        np.random.triangular(OPEN_AIR_MIN, OPEN_AIR_MAX, OPEN_AIR_MAX+300, num_samples//3)
    ])[:num_samples]  # Ensure correct size

    # Environmental conditions
    temp = np.random.normal(25, 10, num_samples)
    temp = np.clip(temp, MIN_TEMP, MAX_TEMP)
    humidity = np.random.normal(50, 25, num_samples)
    humidity = np.clip(humidity, 10, MAX_HUMIDITY)
    hour = np.random.randint(0, 24, num_samples)

    # Add sensor noise
    soil += np.random.normal(0, 50, size=soil.shape).astype(int)
    soil = np.clip(soil, 0, MAX_SENSOR_VALUE)

    water = np.array([generate_water(s,t,h,hr) for s,t,h,hr in zip(soil, temp, humidity, hour)])

    # Visualization
    plt.figure(figsize=(15,6))
    plt.scatter(soil, water, alpha=0.3)
    plt.axvline(IN_WATER_THRESHOLD, color='r', linestyle='--', label='In Water')
    plt.axvline(WET_MOIST_THRESHOLD, color='g', linestyle='--', label='Wet-Moist Transition')
    plt.axvline(OPEN_AIR_MIN, color='b', linestyle='--', label='Open Air/Dry Soil')
    plt.title("Corrected Soil ADC vs Water Need Relationship")
    plt.xlabel("Soil ADC Value")
    plt.ylabel("Water Need (ml)")
    plt.legend()
    plt.show()

    X = generate_features(soil, temp, humidity, hour)
    y = water.reshape(-1, 1)
    return train_test_split(X, y, test_size=0.15, random_state=42)

# Load data
X_train, X_test, y_train, y_test = load_data()

# Enhanced model with fixed learning rate
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(8,)),
        tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(1, activation='linear')
    ])

    model.compile(
        optimizer=tf.keras.optimizers.AdamW(learning_rate=0.005),
        loss=tf.keras.losses.Huber(delta=1.0),
        metrics=['mae', tf.keras.metrics.RootMeanSquaredError()])

    return model

model = create_model()

# Callbacks
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=30,
    restore_best_weights=True)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=10,
    min_lr=1e-5,
    verbose=1)

history = model.fit(
    X_train, y_train,
    epochs=300,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[early_stop, reduce_lr],
    verbose=1)

# Evaluation
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\nModel Metrics:")
print(f"- MAE: {mae:.4f} ml")
print(f"- R²: {r2:.4f}")

# Visualization
plt.figure(figsize=(10, 8))
plt.scatter(y_test, y_pred, alpha=0.4, c='blue', label='Predictions')
max_water = max(np.max(y_test), np.max(y_pred)) * 1.1
plt.plot([0, max_water], [0, max_water], 'r--', label='Perfect Prediction')
plt.fill_between([0, max_water], [0-mae, max_water-mae], [0+mae, max_water+mae],
                 color='orange', alpha=0.1, label=f'MAE: {mae:.2f} ml')
plt.xlabel('Actual Water Need (ml)')
plt.ylabel('Predicted Water Need (ml)')
plt.title(f'Predicted vs Actual\nR²: {r2:.3f}')
plt.legend()
plt.grid(True)
plt.show()

# TFLite conversion
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.uint8

def representative_data_gen():
    for i in range(500):
        yield [X_train[i:i+1].astype(np.float32)]

converter.representative_dataset = representative_data_gen
tflite_model = converter.convert()

with open('water_model.tflite', 'wb') as f:
    f.write(tflite_model)

print("\nModel size:", len(tflite_model), "bytes")

# Generate C header
# !echo "const unsigned char model[] = {" > model.h
# !cat water_model.tflite | xxd -i >> model.h
# !echo "};" >> model.h
# !echo "const unsigned int model_len = sizeof(model);" >> model.h
# Out:
# Epoch 1/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 1.3839 - mae: 1.6828 - root_mean_squared_error: 2.4744 - val_loss: 3.3915 - val_mae: 3.7706 - val_root_mean_squared_error: 4.8121 - learning_rate: 0.0050
# Epoch 2/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5047 - mae: 0.7315 - root_mean_squared_error: 1.1312 - val_loss: 1.2073 - val_mae: 1.5611 - val_root_mean_squared_error: 2.0842 - learning_rate: 0.0050
# Epoch 3/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3482 - mae: 0.5536 - root_mean_squared_error: 0.9041 - val_loss: 0.1430 - val_mae: 0.2602 - val_root_mean_squared_error: 0.4632 - learning_rate: 0.0050
# Epoch 4/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2398 - mae: 0.4237 - root_mean_squared_error: 0.7100 - val_loss: 0.3404 - val_mae: 0.5238 - val_root_mean_squared_error: 1.1363 - learning_rate: 0.0050
# Epoch 5/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2354 - mae: 0.4226 - root_mean_squared_error: 0.7551 - val_loss: 0.4518 - val_mae: 0.7643 - val_root_mean_squared_error: 1.0530 - learning_rate: 0.0050
# Epoch 6/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2731 - mae: 0.4828 - root_mean_squared_error: 0.8297 - val_loss: 0.1940 - val_mae: 0.3070 - val_root_mean_squared_error: 0.8224 - learning_rate: 0.0050
# Epoch 7/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2172 - mae: 0.4026 - root_mean_squared_error: 0.7576 - val_loss: 0.1179 - val_mae: 0.2404 - val_root_mean_squared_error: 0.5264 - learning_rate: 0.0050
# Epoch 8/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1810 - mae: 0.3542 - root_mean_squared_error: 0.6991 - val_loss: 0.1421 - val_mae: 0.2493 - val_root_mean_squared_error: 0.7275 - learning_rate: 0.0050
# Epoch 9/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1517 - mae: 0.3120 - root_mean_squared_error: 0.6402 - val_loss: 0.1100 - val_mae: 0.2376 - val_root_mean_squared_error: 0.5401 - learning_rate: 0.0050
# Epoch 10/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1342 - mae: 0.2868 - root_mean_squared_error: 0.5939 - val_loss: 0.1181 - val_mae: 0.3184 - val_root_mean_squared_error: 0.5138 - learning_rate: 0.0050
# Epoch 11/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1240 - mae: 0.2831 - root_mean_squared_error: 0.5639 - val_loss: 0.2658 - val_mae: 0.4887 - val_root_mean_squared_error: 0.8401 - learning_rate: 0.0050
# Epoch 12/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1383 - mae: 0.2918 - root_mean_squared_error: 0.6410 - val_loss: 0.1117 - val_mae: 0.2756 - val_root_mean_squared_error: 0.5924 - learning_rate: 0.0050
# Epoch 13/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1061 - mae: 0.2423 - root_mean_squared_error: 0.5663 - val_loss: 0.1079 - val_mae: 0.3098 - val_root_mean_squared_error: 0.4627 - learning_rate: 0.0050
# Epoch 14/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0967 - mae: 0.2296 - root_mean_squared_error: 0.5155 - val_loss: 0.1106 - val_mae: 0.2540 - val_root_mean_squared_error: 0.6094 - learning_rate: 0.0050
# Epoch 15/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0985 - mae: 0.2353 - root_mean_squared_error: 0.5398 - val_loss: 0.1110 - val_mae: 0.2845 - val_root_mean_squared_error: 0.5233 - learning_rate: 0.0050
# Epoch 16/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1043 - mae: 0.2497 - root_mean_squared_error: 0.5563 - val_loss: 0.0857 - val_mae: 0.1799 - val_root_mean_squared_error: 0.5614 - learning_rate: 0.0050
# Epoch 17/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0987 - mae: 0.2255 - root_mean_squared_error: 0.5765 - val_loss: 0.0553 - val_mae: 0.1401 - val_root_mean_squared_error: 0.3884 - learning_rate: 0.0050
# Epoch 18/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0906 - mae: 0.2215 - root_mean_squared_error: 0.5356 - val_loss: 0.0675 - val_mae: 0.1683 - val_root_mean_squared_error: 0.4284 - learning_rate: 0.0050
# Epoch 19/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0924 - mae: 0.2281 - root_mean_squared_error: 0.5440 - val_loss: 0.1577 - val_mae: 0.4025 - val_root_mean_squared_error: 0.7109 - learning_rate: 0.0050
# Epoch 20/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0884 - mae: 0.2189 - root_mean_squared_error: 0.5331 - val_loss: 0.0660 - val_mae: 0.1920 - val_root_mean_squared_error: 0.3837 - learning_rate: 0.0050
# Epoch 21/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0852 - mae: 0.2194 - root_mean_squared_error: 0.5047 - val_loss: 0.0757 - val_mae: 0.1992 - val_root_mean_squared_error: 0.5026 - learning_rate: 0.0050
# Epoch 22/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0825 - mae: 0.2125 - root_mean_squared_error: 0.5051 - val_loss: 0.0923 - val_mae: 0.2770 - val_root_mean_squared_error: 0.4685 - learning_rate: 0.0050
# Epoch 23/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0825 - mae: 0.2166 - root_mean_squared_error: 0.4982 - val_loss: 0.0968 - val_mae: 0.1916 - val_root_mean_squared_error: 0.6310 - learning_rate: 0.0050
# Epoch 24/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0841 - mae: 0.2130 - root_mean_squared_error: 0.5099 - val_loss: 0.0837 - val_mae: 0.1655 - val_root_mean_squared_error: 0.5766 - learning_rate: 0.0050
# Epoch 25/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0745 - mae: 0.1921 - root_mean_squared_error: 0.4746 - val_loss: 0.0683 - val_mae: 0.1920 - val_root_mean_squared_error: 0.4686 - learning_rate: 0.0050
# Epoch 26/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0827 - mae: 0.2068 - root_mean_squared_error: 0.5206 - val_loss: 0.0742 - val_mae: 0.1566 - val_root_mean_squared_error: 0.5262 - learning_rate: 0.0050
# Epoch 27/300
# 198/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0873 - mae: 0.2178 - root_mean_squared_error: 0.5331
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0873 - mae: 0.2176 - root_mean_squared_error: 0.5329 - val_loss: 0.1844 - val_mae: 0.3140 - val_root_mean_squared_error: 0.9470 - learning_rate: 0.0050
# Epoch 28/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0781 - mae: 0.1926 - root_mean_squared_error: 0.5086 - val_loss: 0.1074 - val_mae: 0.3477 - val_root_mean_squared_error: 0.4675 - learning_rate: 0.0025
# Epoch 29/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0719 - mae: 0.1945 - root_mean_squared_error: 0.4631 - val_loss: 0.0581 - val_mae: 0.1709 - val_root_mean_squared_error: 0.4212 - learning_rate: 0.0025
# Epoch 30/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0633 - mae: 0.1708 - root_mean_squared_error: 0.4366 - val_loss: 0.0518 - val_mae: 0.1209 - val_root_mean_squared_error: 0.4086 - learning_rate: 0.0025
# Epoch 31/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0601 - mae: 0.1708 - root_mean_squared_error: 0.4177 - val_loss: 0.0640 - val_mae: 0.1378 - val_root_mean_squared_error: 0.4998 - learning_rate: 0.0025
# Epoch 32/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0761 - mae: 0.2019 - root_mean_squared_error: 0.5088 - val_loss: 0.0456 - val_mae: 0.1219 - val_root_mean_squared_error: 0.3883 - learning_rate: 0.0025
# Epoch 33/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0606 - mae: 0.1651 - root_mean_squared_error: 0.4410 - val_loss: 0.0508 - val_mae: 0.1409 - val_root_mean_squared_error: 0.3871 - learning_rate: 0.0025
# Epoch 34/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0787 - mae: 0.2079 - root_mean_squared_error: 0.5017 - val_loss: 0.1580 - val_mae: 0.4697 - val_root_mean_squared_error: 0.5884 - learning_rate: 0.0025
# Epoch 35/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0681 - mae: 0.1931 - root_mean_squared_error: 0.4564 - val_loss: 0.1045 - val_mae: 0.2504 - val_root_mean_squared_error: 0.6235 - learning_rate: 0.0025
# Epoch 36/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0672 - mae: 0.1865 - root_mean_squared_error: 0.4572 - val_loss: 0.0442 - val_mae: 0.1040 - val_root_mean_squared_error: 0.3867 - learning_rate: 0.0025
# Epoch 37/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0586 - mae: 0.1680 - root_mean_squared_error: 0.4109 - val_loss: 0.0622 - val_mae: 0.2139 - val_root_mean_squared_error: 0.3969 - learning_rate: 0.0025
# Epoch 38/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0622 - mae: 0.1685 - root_mean_squared_error: 0.4441 - val_loss: 0.0517 - val_mae: 0.1348 - val_root_mean_squared_error: 0.4044 - learning_rate: 0.0025
# Epoch 39/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0563 - mae: 0.1619 - root_mean_squared_error: 0.4175 - val_loss: 0.0598 - val_mae: 0.1698 - val_root_mean_squared_error: 0.4418 - learning_rate: 0.0025
# Epoch 40/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0559 - mae: 0.1614 - root_mean_squared_error: 0.4107 - val_loss: 0.0626 - val_mae: 0.2211 - val_root_mean_squared_error: 0.3758 - learning_rate: 0.0025
# Epoch 41/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0647 - mae: 0.1741 - root_mean_squared_error: 0.4664 - val_loss: 0.0873 - val_mae: 0.2155 - val_root_mean_squared_error: 0.5939 - learning_rate: 0.0025
# Epoch 42/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0673 - mae: 0.1878 - root_mean_squared_error: 0.4682 - val_loss: 0.0590 - val_mae: 0.1382 - val_root_mean_squared_error: 0.4686 - learning_rate: 0.0025
# Epoch 43/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0591 - mae: 0.1690 - root_mean_squared_error: 0.4253 - val_loss: 0.0778 - val_mae: 0.1836 - val_root_mean_squared_error: 0.5574 - learning_rate: 0.0025
# Epoch 44/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0605 - mae: 0.1648 - root_mean_squared_error: 0.4382 - val_loss: 0.0339 - val_mae: 0.1073 - val_root_mean_squared_error: 0.2764 - learning_rate: 0.0025
# Epoch 45/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0545 - mae: 0.1522 - root_mean_squared_error: 0.4088 - val_loss: 0.0981 - val_mae: 0.1904 - val_root_mean_squared_error: 0.6959 - learning_rate: 0.0025
# Epoch 46/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0669 - mae: 0.1781 - root_mean_squared_error: 0.4756 - val_loss: 0.1113 - val_mae: 0.2369 - val_root_mean_squared_error: 0.7180 - learning_rate: 0.0025
# Epoch 47/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0721 - mae: 0.1865 - root_mean_squared_error: 0.4955 - val_loss: 0.0483 - val_mae: 0.1491 - val_root_mean_squared_error: 0.3752 - learning_rate: 0.0025
# Epoch 48/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0693 - mae: 0.1791 - root_mean_squared_error: 0.4924 - val_loss: 0.0419 - val_mae: 0.1035 - val_root_mean_squared_error: 0.3489 - learning_rate: 0.0025
# Epoch 49/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0606 - mae: 0.1631 - root_mean_squared_error: 0.4450 - val_loss: 0.0300 - val_mae: 0.1044 - val_root_mean_squared_error: 0.2417 - learning_rate: 0.0025
# Epoch 50/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0635 - mae: 0.1777 - root_mean_squared_error: 0.4516 - val_loss: 0.0345 - val_mae: 0.1277 - val_root_mean_squared_error: 0.2790 - learning_rate: 0.0025
# Epoch 51/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0563 - mae: 0.1711 - root_mean_squared_error: 0.4120 - val_loss: 0.0875 - val_mae: 0.1889 - val_root_mean_squared_error: 0.6195 - learning_rate: 0.0025
# Epoch 52/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0701 - mae: 0.1807 - root_mean_squared_error: 0.4926 - val_loss: 0.0498 - val_mae: 0.1204 - val_root_mean_squared_error: 0.3889 - learning_rate: 0.0025
# Epoch 53/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0650 - mae: 0.1750 - root_mean_squared_error: 0.4630 - val_loss: 0.0404 - val_mae: 0.1294 - val_root_mean_squared_error: 0.3422 - learning_rate: 0.0025
# Epoch 54/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0628 - mae: 0.1680 - root_mean_squared_error: 0.4634 - val_loss: 0.1120 - val_mae: 0.2889 - val_root_mean_squared_error: 0.6550 - learning_rate: 0.0025
# Epoch 55/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0713 - mae: 0.1841 - root_mean_squared_error: 0.4976 - val_loss: 0.0359 - val_mae: 0.1248 - val_root_mean_squared_error: 0.2883 - learning_rate: 0.0025
# Epoch 56/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0616 - mae: 0.1626 - root_mean_squared_error: 0.4516 - val_loss: 0.0376 - val_mae: 0.1278 - val_root_mean_squared_error: 0.3067 - learning_rate: 0.0025
# Epoch 57/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0763 - mae: 0.1914 - root_mean_squared_error: 0.5223 - val_loss: 0.0638 - val_mae: 0.1281 - val_root_mean_squared_error: 0.5196 - learning_rate: 0.0025
# Epoch 58/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0690 - mae: 0.1812 - root_mean_squared_error: 0.4814 - val_loss: 0.0496 - val_mae: 0.1536 - val_root_mean_squared_error: 0.4048 - learning_rate: 0.0025
# Epoch 59/300
# 193/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0661 - mae: 0.1680 - root_mean_squared_error: 0.4774
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0662 - mae: 0.1684 - root_mean_squared_error: 0.4779 - val_loss: 0.0861 - val_mae: 0.1844 - val_root_mean_squared_error: 0.6219 - learning_rate: 0.0025
# Epoch 60/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0580 - mae: 0.1593 - root_mean_squared_error: 0.4292 - val_loss: 0.0626 - val_mae: 0.2360 - val_root_mean_squared_error: 0.3926 - learning_rate: 0.0012
# Epoch 61/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0492 - mae: 0.1454 - root_mean_squared_error: 0.3771 - val_loss: 0.0295 - val_mae: 0.0850 - val_root_mean_squared_error: 0.2556 - learning_rate: 0.0012
# Epoch 62/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0496 - mae: 0.1345 - root_mean_squared_error: 0.3964 - val_loss: 0.0402 - val_mae: 0.1348 - val_root_mean_squared_error: 0.3406 - learning_rate: 0.0012
# Epoch 63/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0496 - mae: 0.1396 - root_mean_squared_error: 0.3963 - val_loss: 0.0642 - val_mae: 0.1131 - val_root_mean_squared_error: 0.5362 - learning_rate: 0.0012
# Epoch 64/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0522 - mae: 0.1415 - root_mean_squared_error: 0.4175 - val_loss: 0.0415 - val_mae: 0.1246 - val_root_mean_squared_error: 0.3502 - learning_rate: 0.0012
# Epoch 65/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0522 - mae: 0.1477 - root_mean_squared_error: 0.4149 - val_loss: 0.0550 - val_mae: 0.1606 - val_root_mean_squared_error: 0.4441 - learning_rate: 0.0012
# Epoch 66/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0530 - mae: 0.1519 - root_mean_squared_error: 0.4055 - val_loss: 0.0524 - val_mae: 0.1120 - val_root_mean_squared_error: 0.4564 - learning_rate: 0.0012
# Epoch 67/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0521 - mae: 0.1505 - root_mean_squared_error: 0.4104 - val_loss: 0.0355 - val_mae: 0.1543 - val_root_mean_squared_error: 0.2540 - learning_rate: 0.0012
# Epoch 68/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0433 - mae: 0.1354 - root_mean_squared_error: 0.3594 - val_loss: 0.0511 - val_mae: 0.2122 - val_root_mean_squared_error: 0.3268 - learning_rate: 0.0012
# Epoch 69/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0546 - mae: 0.1625 - root_mean_squared_error: 0.4032 - val_loss: 0.0335 - val_mae: 0.1127 - val_root_mean_squared_error: 0.2812 - learning_rate: 0.0012
# Epoch 70/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0517 - mae: 0.1470 - root_mean_squared_error: 0.4098 - val_loss: 0.0389 - val_mae: 0.0876 - val_root_mean_squared_error: 0.3689 - learning_rate: 0.0012
# Epoch 71/300
# 195/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0512 - mae: 0.1477 - root_mean_squared_error: 0.4065
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0512 - mae: 0.1476 - root_mean_squared_error: 0.4064 - val_loss: 0.0398 - val_mae: 0.1161 - val_root_mean_squared_error: 0.3679 - learning_rate: 0.0012
# Epoch 72/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0396 - mae: 0.1252 - root_mean_squared_error: 0.3283 - val_loss: 0.0315 - val_mae: 0.0685 - val_root_mean_squared_error: 0.3201 - learning_rate: 6.2500e-04
# Epoch 73/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0427 - mae: 0.1292 - root_mean_squared_error: 0.3536 - val_loss: 0.0305 - val_mae: 0.1168 - val_root_mean_squared_error: 0.2685 - learning_rate: 6.2500e-04
# Epoch 74/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0370 - mae: 0.1208 - root_mean_squared_error: 0.3123 - val_loss: 0.0279 - val_mae: 0.0755 - val_root_mean_squared_error: 0.2700 - learning_rate: 6.2500e-04
# Epoch 75/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0429 - mae: 0.1305 - root_mean_squared_error: 0.3595 - val_loss: 0.0253 - val_mae: 0.0647 - val_root_mean_squared_error: 0.2612 - learning_rate: 6.2500e-04
# Epoch 76/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0421 - mae: 0.1229 - root_mean_squared_error: 0.3574 - val_loss: 0.0230 - val_mae: 0.0712 - val_root_mean_squared_error: 0.2098 - learning_rate: 6.2500e-04
# Epoch 77/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0402 - mae: 0.1265 - root_mean_squared_error: 0.3409 - val_loss: 0.0203 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1931 - learning_rate: 6.2500e-04
# Epoch 78/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0370 - mae: 0.1275 - root_mean_squared_error: 0.3121 - val_loss: 0.0272 - val_mae: 0.0825 - val_root_mean_squared_error: 0.2656 - learning_rate: 6.2500e-04
# Epoch 79/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0525 - mae: 0.1436 - root_mean_squared_error: 0.4288 - val_loss: 0.0330 - val_mae: 0.0787 - val_root_mean_squared_error: 0.3437 - learning_rate: 6.2500e-04
# Epoch 80/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0391 - mae: 0.1252 - root_mean_squared_error: 0.3370 - val_loss: 0.0382 - val_mae: 0.0840 - val_root_mean_squared_error: 0.3749 - learning_rate: 6.2500e-04
# Epoch 81/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0433 - mae: 0.1284 - root_mean_squared_error: 0.3735 - val_loss: 0.0282 - val_mae: 0.0804 - val_root_mean_squared_error: 0.2865 - learning_rate: 6.2500e-04
# Epoch 82/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0361 - mae: 0.1197 - root_mean_squared_error: 0.3149 - val_loss: 0.0231 - val_mae: 0.0732 - val_root_mean_squared_error: 0.2284 - learning_rate: 6.2500e-04
# Epoch 83/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0392 - mae: 0.1213 - root_mean_squared_error: 0.3403 - val_loss: 0.0428 - val_mae: 0.1849 - val_root_mean_squared_error: 0.3078 - learning_rate: 6.2500e-04
# Epoch 84/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0396 - mae: 0.1213 - root_mean_squared_error: 0.3450 - val_loss: 0.0206 - val_mae: 0.0758 - val_root_mean_squared_error: 0.1846 - learning_rate: 6.2500e-04
# Epoch 85/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0422 - mae: 0.1342 - root_mean_squared_error: 0.3455 - val_loss: 0.0293 - val_mae: 0.0832 - val_root_mean_squared_error: 0.2980 - learning_rate: 6.2500e-04
# Epoch 86/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0401 - mae: 0.1202 - root_mean_squared_error: 0.3467 - val_loss: 0.0234 - val_mae: 0.0655 - val_root_mean_squared_error: 0.2502 - learning_rate: 6.2500e-04
# Epoch 87/300
# 194/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0349 - mae: 0.1174 - root_mean_squared_error: 0.3030
# Epoch 87: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0350 - mae: 0.1175 - root_mean_squared_error: 0.3045 - val_loss: 0.0259 - val_mae: 0.0827 - val_root_mean_squared_error: 0.2505 - learning_rate: 6.2500e-04
# Epoch 88/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0382 - mae: 0.1172 - root_mean_squared_error: 0.3390 - val_loss: 0.0203 - val_mae: 0.0651 - val_root_mean_squared_error: 0.2082 - learning_rate: 3.1250e-04
# Epoch 89/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0307 - mae: 0.1056 - root_mean_squared_error: 0.2781 - val_loss: 0.0306 - val_mae: 0.0915 - val_root_mean_squared_error: 0.2983 - learning_rate: 3.1250e-04
# Epoch 90/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0382 - mae: 0.1179 - root_mean_squared_error: 0.3414 - val_loss: 0.0265 - val_mae: 0.0882 - val_root_mean_squared_error: 0.2569 - learning_rate: 3.1250e-04
# Epoch 91/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0363 - mae: 0.1137 - root_mean_squared_error: 0.3224 - val_loss: 0.0308 - val_mae: 0.0715 - val_root_mean_squared_error: 0.3166 - learning_rate: 3.1250e-04
# Epoch 92/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0405 - mae: 0.1202 - root_mean_squared_error: 0.3591 - val_loss: 0.0303 - val_mae: 0.0875 - val_root_mean_squared_error: 0.3052 - learning_rate: 3.1250e-04
# Epoch 93/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0368 - mae: 0.1169 - root_mean_squared_error: 0.3317 - val_loss: 0.0230 - val_mae: 0.0945 - val_root_mean_squared_error: 0.2103 - learning_rate: 3.1250e-04
# Epoch 94/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0329 - mae: 0.1135 - root_mean_squared_error: 0.2881 - val_loss: 0.0270 - val_mae: 0.1122 - val_root_mean_squared_error: 0.2251 - learning_rate: 3.1250e-04
# Epoch 95/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0323 - mae: 0.1093 - root_mean_squared_error: 0.2948 - val_loss: 0.0299 - val_mae: 0.0776 - val_root_mean_squared_error: 0.3253 - learning_rate: 3.1250e-04
# Epoch 96/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0330 - mae: 0.1083 - root_mean_squared_error: 0.3035 - val_loss: 0.0187 - val_mae: 0.0612 - val_root_mean_squared_error: 0.1856 - learning_rate: 3.1250e-04
# Epoch 97/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0316 - mae: 0.1027 - root_mean_squared_error: 0.2913 - val_loss: 0.0319 - val_mae: 0.0718 - val_root_mean_squared_error: 0.3413 - learning_rate: 3.1250e-04
# Epoch 98/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0335 - mae: 0.1177 - root_mean_squared_error: 0.2876 - val_loss: 0.0182 - val_mae: 0.0557 - val_root_mean_squared_error: 0.1760 - learning_rate: 3.1250e-04
# Epoch 99/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0343 - mae: 0.1131 - root_mean_squared_error: 0.3069 - val_loss: 0.0428 - val_mae: 0.0972 - val_root_mean_squared_error: 0.4214 - learning_rate: 3.1250e-04
# Epoch 100/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0355 - mae: 0.1107 - root_mean_squared_error: 0.3219 - val_loss: 0.0235 - val_mae: 0.0992 - val_root_mean_squared_error: 0.2168 - learning_rate: 3.1250e-04
# Epoch 101/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0366 - mae: 0.1170 - root_mean_squared_error: 0.3258 - val_loss: 0.0240 - val_mae: 0.0653 - val_root_mean_squared_error: 0.2500 - learning_rate: 3.1250e-04
# Epoch 102/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0358 - mae: 0.1104 - root_mean_squared_error: 0.3248 - val_loss: 0.0374 - val_mae: 0.1016 - val_root_mean_squared_error: 0.3693 - learning_rate: 3.1250e-04
# Epoch 103/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0349 - mae: 0.1124 - root_mean_squared_error: 0.3101 - val_loss: 0.0234 - val_mae: 0.0684 - val_root_mean_squared_error: 0.2505 - learning_rate: 3.1250e-04
# Epoch 104/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0353 - mae: 0.1105 - root_mean_squared_error: 0.3266 - val_loss: 0.0187 - val_mae: 0.0462 - val_root_mean_squared_error: 0.1928 - learning_rate: 3.1250e-04
# Epoch 105/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0373 - mae: 0.1177 - root_mean_squared_error: 0.3326 - val_loss: 0.0217 - val_mae: 0.0875 - val_root_mean_squared_error: 0.2082 - learning_rate: 3.1250e-04
# Epoch 106/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0341 - mae: 0.1120 - root_mean_squared_error: 0.3156 - val_loss: 0.0208 - val_mae: 0.0661 - val_root_mean_squared_error: 0.1891 - learning_rate: 3.1250e-04
# Epoch 107/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0316 - mae: 0.1103 - root_mean_squared_error: 0.2871 - val_loss: 0.0284 - val_mae: 0.0696 - val_root_mean_squared_error: 0.3052 - learning_rate: 3.1250e-04
# Epoch 108/300
# 189/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0318 - mae: 0.1087 - root_mean_squared_error: 0.2896
# Epoch 108: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0319 - mae: 0.1088 - root_mean_squared_error: 0.2904 - val_loss: 0.0192 - val_mae: 0.0822 - val_root_mean_squared_error: 0.1802 - learning_rate: 3.1250e-04
# Epoch 109/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0336 - mae: 0.1089 - root_mean_squared_error: 0.3071 - val_loss: 0.0172 - val_mae: 0.0481 - val_root_mean_squared_error: 0.1765 - learning_rate: 1.5625e-04
# Epoch 110/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0341 - mae: 0.1098 - root_mean_squared_error: 0.3186 - val_loss: 0.0182 - val_mae: 0.0555 - val_root_mean_squared_error: 0.1826 - learning_rate: 1.5625e-04
# Epoch 111/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0327 - mae: 0.1094 - root_mean_squared_error: 0.3024 - val_loss: 0.0187 - val_mae: 0.0578 - val_root_mean_squared_error: 0.2019 - learning_rate: 1.5625e-04
# Epoch 112/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0321 - mae: 0.1015 - root_mean_squared_error: 0.3030 - val_loss: 0.0177 - val_mae: 0.0433 - val_root_mean_squared_error: 0.2013 - learning_rate: 1.5625e-04
# Epoch 113/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0376 - mae: 0.1140 - root_mean_squared_error: 0.3516 - val_loss: 0.0253 - val_mae: 0.0723 - val_root_mean_squared_error: 0.2622 - learning_rate: 1.5625e-04
# Epoch 114/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0358 - mae: 0.1093 - root_mean_squared_error: 0.3341 - val_loss: 0.0208 - val_mae: 0.0842 - val_root_mean_squared_error: 0.1996 - learning_rate: 1.5625e-04
# Epoch 115/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0320 - mae: 0.1050 - root_mean_squared_error: 0.2970 - val_loss: 0.0181 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1782 - learning_rate: 1.5625e-04
# Epoch 116/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0313 - mae: 0.1058 - root_mean_squared_error: 0.2786 - val_loss: 0.0174 - val_mae: 0.0554 - val_root_mean_squared_error: 0.1761 - learning_rate: 1.5625e-04
# Epoch 117/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0307 - mae: 0.1047 - root_mean_squared_error: 0.2806 - val_loss: 0.0194 - val_mae: 0.0475 - val_root_mean_squared_error: 0.1999 - learning_rate: 1.5625e-04
# Epoch 118/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0333 - mae: 0.1108 - root_mean_squared_error: 0.3147 - val_loss: 0.0183 - val_mae: 0.0545 - val_root_mean_squared_error: 0.1830 - learning_rate: 1.5625e-04
# Epoch 119/300
# 197/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0341 - mae: 0.1082 - root_mean_squared_error: 0.3164
# Epoch 119: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0341 - mae: 0.1082 - root_mean_squared_error: 0.3162 - val_loss: 0.0172 - val_mae: 0.0553 - val_root_mean_squared_error: 0.1686 - learning_rate: 1.5625e-04
# Epoch 120/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0282 - mae: 0.0971 - root_mean_squared_error: 0.2710 - val_loss: 0.0151 - val_mae: 0.0419 - val_root_mean_squared_error: 0.1437 - learning_rate: 7.8125e-05
# Epoch 121/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0296 - mae: 0.1018 - root_mean_squared_error: 0.2822 - val_loss: 0.0173 - val_mae: 0.0631 - val_root_mean_squared_error: 0.1651 - learning_rate: 7.8125e-05
# Epoch 122/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0306 - mae: 0.1038 - root_mean_squared_error: 0.2787 - val_loss: 0.0160 - val_mae: 0.0586 - val_root_mean_squared_error: 0.1499 - learning_rate: 7.8125e-05
# Epoch 123/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0383 - mae: 0.1154 - root_mean_squared_error: 0.3397 - val_loss: 0.0173 - val_mae: 0.0513 - val_root_mean_squared_error: 0.1696 - learning_rate: 7.8125e-05
# Epoch 124/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0333 - mae: 0.1074 - root_mean_squared_error: 0.3064 - val_loss: 0.0173 - val_mae: 0.0617 - val_root_mean_squared_error: 0.1644 - learning_rate: 7.8125e-05
# Epoch 125/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0309 - mae: 0.1049 - root_mean_squared_error: 0.2901 - val_loss: 0.0168 - val_mae: 0.0494 - val_root_mean_squared_error: 0.1841 - learning_rate: 7.8125e-05
# Epoch 126/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0317 - mae: 0.1012 - root_mean_squared_error: 0.3057 - val_loss: 0.0182 - val_mae: 0.0745 - val_root_mean_squared_error: 0.1670 - learning_rate: 7.8125e-05
# Epoch 127/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0326 - mae: 0.1053 - root_mean_squared_error: 0.3069 - val_loss: 0.0165 - val_mae: 0.0580 - val_root_mean_squared_error: 0.1629 - learning_rate: 7.8125e-05
# Epoch 128/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0347 - mae: 0.1093 - root_mean_squared_error: 0.3208 - val_loss: 0.0186 - val_mae: 0.0550 - val_root_mean_squared_error: 0.1883 - learning_rate: 7.8125e-05
# Epoch 129/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0300 - mae: 0.1032 - root_mean_squared_error: 0.2822 - val_loss: 0.0172 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1741 - learning_rate: 7.8125e-05
# Epoch 130/300
# 191/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0293 - mae: 0.1027 - root_mean_squared_error: 0.2725
# Epoch 130: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0293 - mae: 0.1027 - root_mean_squared_error: 0.2726 - val_loss: 0.0165 - val_mae: 0.0473 - val_root_mean_squared_error: 0.1829 - learning_rate: 7.8125e-05
# Epoch 131/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0316 - mae: 0.1053 - root_mean_squared_error: 0.2843 - val_loss: 0.0162 - val_mae: 0.0514 - val_root_mean_squared_error: 0.1720 - learning_rate: 3.9062e-05
# Epoch 132/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0321 - mae: 0.1063 - root_mean_squared_error: 0.2937 - val_loss: 0.0163 - val_mae: 0.0500 - val_root_mean_squared_error: 0.1598 - learning_rate: 3.9062e-05
# Epoch 133/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0305 - mae: 0.1024 - root_mean_squared_error: 0.2787 - val_loss: 0.0171 - val_mae: 0.0647 - val_root_mean_squared_error: 0.1590 - learning_rate: 3.9062e-05
# Epoch 134/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0287 - mae: 0.1013 - root_mean_squared_error: 0.2692 - val_loss: 0.0167 - val_mae: 0.0531 - val_root_mean_squared_error: 0.1589 - learning_rate: 3.9062e-05
# Epoch 135/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0326 - mae: 0.1046 - root_mean_squared_error: 0.3061 - val_loss: 0.0164 - val_mae: 0.0551 - val_root_mean_squared_error: 0.1560 - learning_rate: 3.9062e-05
# Epoch 136/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0301 - mae: 0.1054 - root_mean_squared_error: 0.2787 - val_loss: 0.0158 - val_mae: 0.0461 - val_root_mean_squared_error: 0.1574 - learning_rate: 3.9062e-05
# Epoch 137/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0297 - mae: 0.1028 - root_mean_squared_error: 0.2771 - val_loss: 0.0150 - val_mae: 0.0429 - val_root_mean_squared_error: 0.1421 - learning_rate: 3.9062e-05
# Epoch 138/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0327 - mae: 0.1020 - root_mean_squared_error: 0.3112 - val_loss: 0.0182 - val_mae: 0.0689 - val_root_mean_squared_error: 0.1698 - learning_rate: 3.9062e-05
# Epoch 139/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0288 - mae: 0.0992 - root_mean_squared_error: 0.2747 - val_loss: 0.0158 - val_mae: 0.0447 - val_root_mean_squared_error: 0.1523 - learning_rate: 3.9062e-05
# Epoch 140/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0278 - mae: 0.1001 - root_mean_squared_error: 0.2521 - val_loss: 0.0157 - val_mae: 0.0476 - val_root_mean_squared_error: 0.1519 - learning_rate: 3.9062e-05
# Epoch 141/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0317 - mae: 0.1039 - root_mean_squared_error: 0.2943 - val_loss: 0.0181 - val_mae: 0.0671 - val_root_mean_squared_error: 0.1710 - learning_rate: 3.9062e-05
# Epoch 142/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0318 - mae: 0.1040 - root_mean_squared_error: 0.2917 - val_loss: 0.0168 - val_mae: 0.0537 - val_root_mean_squared_error: 0.1811 - learning_rate: 3.9062e-05
# Epoch 143/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0328 - mae: 0.1055 - root_mean_squared_error: 0.3039 - val_loss: 0.0172 - val_mae: 0.0588 - val_root_mean_squared_error: 0.1663 - learning_rate: 3.9062e-05
# Epoch 144/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0379 - mae: 0.1125 - root_mean_squared_error: 0.3162 - val_loss: 0.0169 - val_mae: 0.0509 - val_root_mean_squared_error: 0.1642 - learning_rate: 3.9062e-05
# Epoch 145/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0325 - mae: 0.1026 - root_mean_squared_error: 0.3112 - val_loss: 0.0194 - val_mae: 0.0707 - val_root_mean_squared_error: 0.1835 - learning_rate: 3.9062e-05
# Epoch 146/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0281 - mae: 0.0988 - root_mean_squared_error: 0.2675 - val_loss: 0.0170 - val_mae: 0.0520 - val_root_mean_squared_error: 0.1667 - learning_rate: 3.9062e-05
# Epoch 147/300
# 197/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0291 - mae: 0.1004 - root_mean_squared_error: 0.2699
# Epoch 147: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0291 - mae: 0.1004 - root_mean_squared_error: 0.2702 - val_loss: 0.0172 - val_mae: 0.0580 - val_root_mean_squared_error: 0.1659 - learning_rate: 3.9062e-05
# Epoch 148/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0310 - mae: 0.1024 - root_mean_squared_error: 0.2972 - val_loss: 0.0169 - val_mae: 0.0557 - val_root_mean_squared_error: 0.1671 - learning_rate: 1.9531e-05
# Epoch 149/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0303 - mae: 0.1036 - root_mean_squared_error: 0.2878 - val_loss: 0.0171 - val_mae: 0.0617 - val_root_mean_squared_error: 0.1693 - learning_rate: 1.9531e-05
# Epoch 150/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0300 - mae: 0.1007 - root_mean_squared_error: 0.2867 - val_loss: 0.0172 - val_mae: 0.0559 - val_root_mean_squared_error: 0.1732 - learning_rate: 1.9531e-05
# Epoch 151/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0302 - mae: 0.0995 - root_mean_squared_error: 0.2869 - val_loss: 0.0185 - val_mae: 0.0640 - val_root_mean_squared_error: 0.1790 - learning_rate: 1.9531e-05
# Epoch 152/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0299 - mae: 0.0988 - root_mean_squared_error: 0.2828 - val_loss: 0.0165 - val_mae: 0.0477 - val_root_mean_squared_error: 0.1626 - learning_rate: 1.9531e-05
# Epoch 153/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0323 - mae: 0.1050 - root_mean_squared_error: 0.3078 - val_loss: 0.0165 - val_mae: 0.0509 - val_root_mean_squared_error: 0.1674 - learning_rate: 1.9531e-05
# Epoch 154/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0296 - mae: 0.0999 - root_mean_squared_error: 0.2802 - val_loss: 0.0170 - val_mae: 0.0574 - val_root_mean_squared_error: 0.1632 - learning_rate: 1.9531e-05
# Epoch 155/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0312 - mae: 0.1037 - root_mean_squared_error: 0.2868 - val_loss: 0.0171 - val_mae: 0.0586 - val_root_mean_squared_error: 0.1628 - learning_rate: 1.9531e-05
# Epoch 156/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0326 - mae: 0.1084 - root_mean_squared_error: 0.2990 - val_loss: 0.0164 - val_mae: 0.0535 - val_root_mean_squared_error: 0.1569 - learning_rate: 1.9531e-05
# Epoch 157/300
# 194/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0299 - mae: 0.0991 - root_mean_squared_error: 0.2790
# Epoch 157: ReduceLROnPlateau reducing learning rate to 1e-05.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0299 - mae: 0.0991 - root_mean_squared_error: 0.2792 - val_loss: 0.0172 - val_mae: 0.0604 - val_root_mean_squared_error: 0.1622 - learning_rate: 1.9531e-05
# Epoch 158/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0304 - mae: 0.1027 - root_mean_squared_error: 0.2866 - val_loss: 0.0161 - val_mae: 0.0528 - val_root_mean_squared_error: 0.1522 - learning_rate: 1.0000e-05
# Epoch 159/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0265 - mae: 0.0973 - root_mean_squared_error: 0.2513 - val_loss: 0.0163 - val_mae: 0.0535 - val_root_mean_squared_error: 0.1553 - learning_rate: 1.0000e-05
# Epoch 160/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0255 - mae: 0.0943 - root_mean_squared_error: 0.2449 - val_loss: 0.0161 - val_mae: 0.0514 - val_root_mean_squared_error: 0.1538 - learning_rate: 1.0000e-05
# Epoch 161/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0296 - mae: 0.1018 - root_mean_squared_error: 0.2681 - val_loss: 0.0168 - val_mae: 0.0540 - val_root_mean_squared_error: 0.1609 - learning_rate: 1.0000e-05
# Epoch 162/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0306 - mae: 0.1022 - root_mean_squared_error: 0.2904 - val_loss: 0.0165 - val_mae: 0.0531 - val_root_mean_squared_error: 0.1580 - learning_rate: 1.0000e-05
# Epoch 163/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0292 - mae: 0.1002 - root_mean_squared_error: 0.2767 - val_loss: 0.0173 - val_mae: 0.0576 - val_root_mean_squared_error: 0.1674 - learning_rate: 1.0000e-05
# Epoch 164/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0313 - mae: 0.1025 - root_mean_squared_error: 0.2944 - val_loss: 0.0162 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1535 - learning_rate: 1.0000e-05
# Epoch 165/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0320 - mae: 0.1037 - root_mean_squared_error: 0.3020 - val_loss: 0.0158 - val_mae: 0.0510 - val_root_mean_squared_error: 0.1518 - learning_rate: 1.0000e-05
# Epoch 166/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0286 - mae: 0.0987 - root_mean_squared_error: 0.2745 - val_loss: 0.0156 - val_mae: 0.0504 - val_root_mean_squared_error: 0.1495 - learning_rate: 1.0000e-05
# Epoch 167/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0315 - mae: 0.1025 - root_mean_squared_error: 0.3037 - val_loss: 0.0158 - val_mae: 0.0499 - val_root_mean_squared_error: 0.1525 - learning_rate: 1.0000e-05
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Model Metrics:
# - MAE: 0.0429 ml
# - R²: 0.9989
# Saved artifact at '/tmp/tmpgcbb2m9j'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 8), dtype=tf.float32, name='keras_tensor_42')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   139948693138576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139948689543376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139948689552400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139948689546256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139948689550096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139948689544528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139948689547600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139948689544336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139948689547024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139948689549712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139948689551440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139948689550864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
# Model size: 20776 bytes
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
